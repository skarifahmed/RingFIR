# %%
import numpy as np
import h5py
def read_train_hdf5():
    images, labels = [], []
    # Open the HDF5 file
    file = h5py.File("/content/drive/My Drive/images/dataset.hdf5", "r+")
    images = np.array(file["/train_img"]).astype("uint8")
    labels = np.array(file["/train_labels"]).astype("uint8")
    return images, labels

def read_query_hdf5():
    images, labels = [], []
    # Open the HDF5 file
    file = h5py.File("/content/drive/My Drive/images/query.hdf5", "r+")
    images = np.array(file["/train_img"]).astype("uint8")
    labels = np.array(file["/train_labels"]).astype("uint8")
    return images, labels

# %%
train_img,train_labels=read_train_hdf5()
query_img,query_labels=read_query_hdf5()

# %%
from keras.applications.densenet import DenseNet169
from keras.preprocessing import image
from keras.applications.densenet import preprocess_input, decode_predictions
from keras.models import Model
import numpy as np
from os import listdir, walk
from os.path import isfile, join
import itertools

# %%
def predict(img, model: Model):
    #print(img_path)
    #img = image.load_img(img, target_size=(299, 299,3))
    #x = image.img_to_array(img)
    x=img
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return model.predict(x)
def findDifference(f1, f2):
    return np.linalg.norm(f1-f2)

# %%
model = DenseNet169(weights='imagenet')
total_galery=train_img.shape[0]
all_feature=[]
for i in range(total_galery):
  feature_vector_train=predict(train_img[i],model)
  all_feature.append(feature_vector_train)
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels.h5
# 33193984/33188688 [==============================] - 2s 0us/step

# %%
def findDist(query_img,all_feature,model):
  res=[]
  feature_vector_query=predict(query_img,model)
  for i in range(len(all_feature)):
    dist=findDifference(all_feature[i],feature_vector_query)
    res.append(dist)
  return res

# %%
import matplotlib.pyplot as plt
import sys

# %%
#file1 = open('/content/drive/My Drive/images/output.txt', 'a')
#sys.stdout = file1
top1=0
top2=0
top3=0
top4=0
top5=0
top6=0
top7=0
top8=0
top9=0
top10=0
for j in range(len(query_img)):
  res=findDist(query_img[j],all_feature,model)
  ind=np.argsort(res)
  if(train_labels[ind[0]]==query_labels[j]):
    top1=top1+1
  for k in range(2):
    if(train_labels[ind[k]]==query_labels[j]):
      top2=top2+1
      break
  for k in range(3):
    if(train_labels[ind[k]]==query_labels[j]):
      top3=top3+1
      break
  for k in range(4):
    if(train_labels[ind[k]]==query_labels[j]):
      top4=top4+1
      break
  for k in range(5):
    if(train_labels[ind[k]]==query_labels[j]):
      top5=top5+1
      break
  for k in range(6):
    if(train_labels[ind[k]]==query_labels[j]):
      top6=top6+1
      break
  for k in range(7):
    if(train_labels[ind[k]]==query_labels[j]):
      top7=top7+1
      break
  for k in range(8):
    if(train_labels[ind[k]]==query_labels[j]):
      top8=top8+1
      break
  for k in range(9):
    if(train_labels[ind[k]]==query_labels[j]):
      top9=top9+1
      break
  for k in range(10):
    if(train_labels[ind[k]]==query_labels[j]):
      top10=top10+1
      break
  print("Top 1 best match with the query image")
  print("Query label :"+str(query_labels[j]))
  print(train_labels[ind[k]])
   
  print("Top 5 best match with the query image")
  print("Query label :"+str(query_labels[j]))
  for k in range(5):
    print(train_labels[ind[k]])
    #print(ind[k])
    
  print("Top 10 best match with the query image")
  print("Query label :"+str(query_labels[j]))
  for k in range(10):
    print(train_labels[ind[k]])
    #print(ind[k])
    
top1_acc=(top1/len(query_img))*100
top2_acc=(top2/len(query_img))*100
top3_acc=(top3/len(query_img))*100
top4_acc=(top4/len(query_img))*100
top5_acc=(top5/len(query_img))*100
top6_acc=(top6/len(query_img))*100
top7_acc=(top7/len(query_img))*100
top8_acc=(top8/len(query_img))*100
top9_acc=(top9/len(query_img))*100
top10_acc=(top10/len(query_img))*100
print("Top1 Accuracy="+str(top1_acc))
print("Top2 Accuracy="+str(top2_acc))
print("Top3 Accuracy="+str(top3_acc))
print("Top4 Accuracy="+str(top4_acc))
print("Top5 Accuracy="+str(top5_acc))
print("Top6 Accuracy="+str(top6_acc))
print("Top7 Accuracy="+str(top7_acc))
print("Top8 Accuracy="+str(top8_acc))
print("Top9 Accuracy="+str(top9_acc))
print("Top10 Accuracy="+str(top10_acc))
#print(top1_acc,top5_acc)
#file1.close()
# Out:
# Top 1 best match with the query image
# Query label :30
# 30
# Top 5 best match with the query image
# Query label :30
# 7
# 17
# 44
# 17
# 18
# Top 10 best match with the query image
# Query label :30
# 7
# 17
# 44
# 17
# 18
# 40
# 40
# 45
# 40
# 30
# Top 1 best match with the query image
# Query label :21
# 21
# Top 5 best match with the query image
# Query label :21
# 21
# 40
# 30
# 19
# 19
# Top 10 best match with the query image
# Query label :21
# 21
# 40
# 30
# 19
# 19
# 40
# 30
# 31
# 17
# 17
# Top 1 best match with the query image
# Query label :18
# 18
# Top 5 best match with the query image
# Query label :18
# 17
# 31
# 17
# 25
# 24
# Top 10 best match with the query image
# Query label :18
# 17
# 31
# 17
# 25
# 24
# 10
# 18
# 31
# 22
# 19
# Top 1 best match with the query image
# Query label :22
# 22
# Top 5 best match with the query image
# Query label :22
# 22
# 40
# 30
# 30
# 18
# Top 10 best match with the query image
# Query label :22
# 22
# 40
# 30
# 30
# 18
# 31
# 38
# 39
# 39
# 45
# Top 1 best match with the query image
# Query label :31
# 25
# Top 5 best match with the query image
# Query label :31
# 25
# 13
# 35
# 26
# 38
# Top 10 best match with the query image
# Query label :31
# 25
# 13
# 35
# 26
# 38
# 39
# 13
# 10
# 25
# 25
# Top 1 best match with the query image
# Query label :27
# 27
# Top 5 best match with the query image
# Query label :27
# 29
# 39
# 40
# 28
# 41
# Top 10 best match with the query image
# Query label :27
# 29
# 39
# 40
# 28
# 41
# 8
# 37
# 29
# 27
# 43
# Top 1 best match with the query image
# Query label :43
# 45
# Top 5 best match with the query image
# Query label :43
# 42
# 38
# 22
# 20
# 30
# Top 10 best match with the query image
# Query label :43
# 42
# 38
# 22
# 20
# 30
# 17
# 42
# 40
# 41
# 45
# Top 1 best match with the query image
# Query label :39
# 13
# Top 5 best match with the query image
# Query label :39
# 10
# 21
# 30
# 19
# 42
# Top 10 best match with the query image
# Query label :39
# 10
# 21
# 30
# 19
# 42
# 41
# 21
# 19
# 41
# 13
# Top 1 best match with the query image
# Query label :41
# 4
# Top 5 best match with the query image
# Query label :41
# 29
# 43
# 29
# 20
# 11
# Top 10 best match with the query image
# Query label :41
# 29
# 43
# 29
# 20
# 11
# 34
# 6
# 34
# 8
# 4
# Top 1 best match with the query image
# Query label :28
# 28
# Top 5 best match with the query image
# Query label :28
# 28
# 38
# 27
# 43
# 41
# Top 10 best match with the query image
# Query label :28
# 28
# 38
# 27
# 43
# 41
# 21
# 27
# 45
# 36
# 27
# Top 1 best match with the query image
# Query label :2
# 2
# Top 5 best match with the query image
# Query label :2
# 24
# 39
# 2
# 25
# 23
# Top 10 best match with the query image
# Query label :2
# 24
# 39
# 2
# 25
# 23
# 24
# 1
# 24
# 24
# 4
# Top 1 best match with the query image
# Query label :11
# 11
# Top 5 best match with the query image
# Query label :11
# 26
# 7
# 6
# 11
# 7
# Top 10 best match with the query image
# Query label :11
# 26
# 7
# 6
# 11
# 7
# 10
# 34
# 30
# 7
# 43
# Top 1 best match with the query image
# Query label :12
# 12
# Top 5 best match with the query image
# Query label :12
# 26
# 27
# 26
# 27
# 12
# Top 10 best match with the query image
# Query label :12
# 26
# 27
# 26
# 27
# 12
# 27
# 27
# 36
# 32
# 6
# Top 1 best match with the query image
# Query label :6
# 26
# Top 5 best match with the query image
# Query label :6
# 5
# 25
# 13
# 18
# 38
# Top 10 best match with the query image
# Query label :6
# 5
# 25
# 13
# 18
# 38
# 32
# 32
# 14
# 8
# 26
# Top 1 best match with the query image
# Query label :1
# 42
# Top 5 best match with the query image
# Query label :1
# 45
# 27
# 16
# 45
# 27
# Top 10 best match with the query image
# Query label :1
# 45
# 27
# 16
# 45
# 27
# 27
# 2
# 27
# 16
# 42
# Top 1 best match with the query image
# Query label :14
# 1
# Top 5 best match with the query image
# Query label :14
# 24
# 31
# 24
# 2
# 43
# Top 10 best match with the query image
# Query label :14
# 24
# 31
# 24
# 2
# 43
# 45
# 2
# 4
# 24
# 1
# Top 1 best match with the query image
# Query label :24
# 24
# Top 5 best match with the query image
# Query label :24
# 12
# 11
# 24
# 24
# 24
# Top 10 best match with the query image
# Query label :24
# 12
# 11
# 24
# 24
# 24
# 37
# 6
# 35
# 32
# 43
# Top 1 best match with the query image
# Query label :40
# 18
# Top 5 best match with the query image
# Query label :40
# 30
# 17
# 17
# 30
# 30
# Top 10 best match with the query image
# Query label :40
# 30
# 17
# 17
# 30
# 30
# 18
# 30
# 17
# 30
# 18
# Top 1 best match with the query image
# Query label :44
# 44
# Top 5 best match with the query image
# Query label :44
# 44
# 40
# 38
# 30
# 45
# Top 10 best match with the query image
# Query label :44
# 44
# 40
# 38
# 30
# 45
# 30
# 17
# 18
# 30
# 41
# Top 1 best match with the query image
# Query label :34
# 34
# Top 5 best match with the query image
# Query label :34
# 4
# 6
# 4
# 17
# 24
# Top 10 best match with the query image
# Query label :34
# 4
# 6
# 4
# 17
# 24
# 25
# 24
# 6
# 26
# 34
# Top 1 best match with the query image
# Query label :29
# 29
# Top 5 best match with the query image
# Query label :29
# 27
# 46
# 7
# 29
# 41
# Top 10 best match with the query image
# Query label :29
# 27
# 46
# 7
# 29
# 41
# 28
# 12
# 31
# 28
# 46
# Top 1 best match with the query image
# Query label :33
# 36
# Top 5 best match with the query image
# Query label :33
# 14
# 18
# 18
# 40
# 28
# Top 10 best match with the query image
# Query label :33
# 14
# 18
# 18
# 40
# 28
# 27
# 24
# 40
# 21
# 36
# Top 1 best match with the query image
# Query label :16
# 7
# Top 5 best match with the query image
# Query label :16
# 11
# 6
# 27
# 27
# 30
# Top 10 best match with the query image
# Query label :16
# 11
# 6
# 27
# 27
# 30
# 7
# 3
# 6
# 4
# 7
# Top 1 best match with the query image
# Query label :17
# 20
# Top 5 best match with the query image
# Query label :17
# 38
# 18
# 18
# 18
# 42
# Top 10 best match with the query image
# Query label :17
# 38
# 18
# 18
# 18
# 42
# 24
# 18
# 18
# 40
# 20
# Top 1 best match with the query image
# Query label :38
# 19
# Top 5 best match with the query image
# Query label :38
# 22
# 45
# 40
# 22
# 40
# Top 10 best match with the query image
# Query label :38
# 22
# 45
# 40
# 22
# 40
# 40
# 40
# 22
# 40
# 19
# Top 1 best match with the query image
# Query label :42
# 38
# Top 5 best match with the query image
# Query label :42
# 11
# 26
# 35
# 18
# 26
# Top 10 best match with the query image
# Query label :42
# 11
# 26
# 35
# 18
# 26
# 26
# 27
# 26
# 36
# 38
# Top 1 best match with the query image
# Query label :13
# 13
# Top 5 best match with the query image
# Query label :13
# 17
# 40
# 31
# 2
# 2
# Top 10 best match with the query image
# Query label :13
# 17
# 40
# 31
# 2
# 2
# 24
# 18
# 38
# 13
# 13
# Top 1 best match with the query image
# Query label :15
# 15
# Top 5 best match with the query image
# Query label :15
# 25
# 3
# 15
# 3
# 13
# Top 10 best match with the query image
# Query label :15
# 25
# 3
# 15
# 3
# 13
# 14
# 4
# 24
# 20
# 19
# Top 1 best match with the query image
# Query label :20
# 15
# Top 5 best match with the query image
# Query label :20
# 38
# 23
# 17
# 30
# 30
# Top 10 best match with the query image
# Query label :20
# 38
# 23
# 17
# 30
# 30
# 24
# 17
# 21
# 44
# 15
# Top 1 best match with the query image
# Query label :7
# 46
# Top 5 best match with the query image
# Query label :7
# 46
# 46
# 12
# 46
# 9
# Top 10 best match with the query image
# Query label :7
# 46
# 46
# 12
# 46
# 9
# 46
# 46
# 8
# 29
# 46
# Top 1 best match with the query image
# Query label :37
# 12
# Top 5 best match with the query image
# Query label :37
# 11
# 8
# 35
# 28
# 7
# Top 10 best match with the query image
# Query label :37
# 11
# 8
# 35
# 28
# 7
# 46
# 29
# 8
# 46
# 12
# Top 1 best match with the query image
# Query label :9
# 8
# Top 5 best match with the query image
# Query label :9
# 8
# 28
# 7
# 3
# 3
# Top 10 best match with the query image
# Query label :9
# 8
# 28
# 7
# 3
# 3
# 41
# 20
# 32
# 45
# 8
# Top 1 best match with the query image
# Query label :10
# 10
# Top 5 best match with the query image
# Query label :10
# 42
# 36
# 3
# 16
# 3
# Top 10 best match with the query image
# Query label :10
# 42
# 36
# 3
# 16
# 3
# 41
# 45
# 31
# 45
# 10
# Top 1 best match with the query image
# Query label :8
# 9
# Top 5 best match with the query image
# Query label :8
# 46
# 46
# 7
# 5
# 46
# Top 10 best match with the query image
# Query label :8
# 46
# 46
# 7
# 5
# 46
# 7
# 46
# 12
# 9
# 9
# Top 1 best match with the query image
# Query label :4
# 4
# Top 5 best match with the query image
# Query label :4
# 5
# 32
# 8
# 26
# 29
# Top 10 best match with the query image
# Query label :4
# 5
# 32
# 8
# 26
# 29
# 4
# 35
# 26
# 28
# 11
# Top 1 best match with the query image
# Query label :3
# 8
# Top 5 best match with the query image
# Query label :3
# 38
# 27
# 46
# 29
# 9
# Top 10 best match with the query image
# Query label :3
# 38
# 27
# 46
# 29
# 9
# 12
# 7
# 9
# 42
# 8
# Top 1 best match with the query image
# Query label :5
# 41
# Top 5 best match with the query image
# Query label :5
# 12
# 26
# 7
# 9
# 26
# Top 10 best match with the query image
# Query label :5
# 12
# 26
# 7
# 9
# 26
# 40
# 41
# 7
# 29
# 41
# Top 1 best match with the query image
# Query label :32
# 44
# Top 5 best match with the query image
# Query label :32
# 29
# 27
# 29
# 27
# 41
# Top 10 best match with the query image
# Query label :32
# 29
# 27
# 29
# 27
# 41
# 41
# 38
# 38
# 28
# 44
# Top 1 best match with the query image
# Query label :46
# 46
# Top 5 best match with the query image
# Query label :46
# 46
# 46
# 5
# 29
# 8
# Top 10 best match with the query image
# Query label :46
# 46
# 46
# 5
# 29
# 8
# 4
# 46
# 46
# 12
# 9
# Top 1 best match with the query image
# Query label :36
# 31
# Top 5 best match with the query image
# Query label :36
# 41
# 10
# 3
# 45
# 7
# Top 10 best match with the query image
# Query label :36
# 41
# 10
# 3
# 45
# 7
# 45
# 46
# 19
# 44
# 31
# Top 1 best match with the query image
# Query label :45
# 45
# Top 5 best match with the query image
# Query label :45
# 45
# 41
# 3
# 44
# 27
# Top 10 best match with the query image
# Query label :45
# 45
# 41
# 3
# 44
# 27
# 44
# 36
# 7
# 9
# 46
# Top 1 best match with the query image
# Query label :19
# 40
# Top 5 best match with the query image
# Query label :19
# 31
# 24
# 24
# 24
# 18
# Top 10 best match with the query image
# Query label :19
# 31
# 24
# 24
# 24
# 18
# 17
# 18
# 39
# 17
# 40
# Top 1 best match with the query image
# Query label :26
# 4
# Top 5 best match with the query image
# Query label :26
# 5
# 34
# 34
# 11
# 11
# Top 10 best match with the query image
# Query label :26
# 5
# 34
# 34
# 11
# 11
# 2
# 44
# 8
# 34
# 4
# Top 1 best match with the query image
# Query label :23
# 18
# Top 5 best match with the query image
# Query label :23
# 40
# 18
# 39
# 40
# 18
# Top 10 best match with the query image
# Query label :23
# 40
# 18
# 39
# 40
# 18
# 40
# 18
# 24
# 18
# 18
# Top 1 best match with the query image
# Query label :35
# 35
# Top 5 best match with the query image
# Query label :35
# 28
# 32
# 32
# 8
# 26
# Top 10 best match with the query image
# Query label :35
# 28
# 32
# 32
# 8
# 26
# 35
# 4
# 32
# 5
# 28
# Top 1 best match with the query image
# Query label :25
# 25
# Top 5 best match with the query image
# Query label :25
# 24
# 31
# 17
# 25
# 39
# Top 10 best match with the query image
# Query label :25
# 24
# 31
# 17
# 25
# 39
# 13
# 45
# 39
# 39
# 17
# Top1 Accuracy=13.043478260869565
# Top2 Accuracy=13.043478260869565
# Top3 Accuracy=19.565217391304348
# Top4 Accuracy=26.08695652173913
# Top5 Accuracy=28.26086956521739
# Top6 Accuracy=32.608695652173914
# Top7 Accuracy=34.78260869565217
# Top8 Accuracy=34.78260869565217
# Top9 Accuracy=39.130434782608695
# Top10 Accuracy=45.65217391304348

# %%
print(res)
print(ind)
# Out:
# [0.503371, 0.51349556, 0.50934476, 0.59682924, 0.5701374, 0.7181389, 0.42321625, 0.5064222, 0.56767213, 0.5199799, 0.45498902, 0.49012116, 0.50277835, 0.53908354, 0.8113902, 0.8193694, 0.4036233, 0.424241, 0.58334094, 0.49727958, 0.52959895, 0.54813063, 0.3898233, 0.49328643, 0.6845526, 0.48065138, 0.6067097, 0.53002405, 0.70875657, 0.6168866, 0.5159183, 0.54018545, 0.7846859, 0.795987, 0.4754219, 0.6766651, 0.7357021, 0.68431336, 0.51142746, 0.70288324, 0.4871192, 0.61625046, 0.69540167, 0.5714719, 0.85609037, 0.64010286, 0.7947076, 0.4983373, 0.68028027, 0.9291605, 0.57958174, 0.80175525, 0.57796603, 0.5556426, 0.5968194, 0.61735266, 0.6343615, 0.44099137, 0.68634295, 0.45000428, 0.4696117, 0.6442584, 0.40417618, 0.81503797, 0.40762496, 0.853263, 0.6086149, 0.7478848, 0.44269407, 0.381126, 0.57127714, 0.65098464, 0.47882032, 0.70712084, 0.71304905, 0.6822064, 0.5791014, 0.64110225, 0.53972137, 0.6160655, 0.43687633, 0.43986043, 0.51337457, 0.8044161, 0.6700077, 0.52924424, 0.41860512, 0.6527177, 0.9183521, 0.46041316, 0.9306158, 0.48907962, 0.6499685, 0.87922806, 0.72554886, 0.9743466, 0.8250792, 0.82026494, 1.0572262, 0.75581527, 1.0517741, 0.49593478, 0.5898589, 0.5425967, 0.63854355, 1.0035596, 0.56454766, 0.60520744, 0.5625728, 0.88898385, 0.6819531, 0.9902811, 0.8154461, 0.4768136, 0.83148515, 0.62805814, 0.51680034, 0.76904595, 0.89947087, 0.38281405, 0.60422176, 0.4435249, 0.98718065, 0.6585293, 0.5385824, 0.6554476, 0.6269544, 0.67715424, 0.48943296, 0.626086, 0.478957, 0.9168058, 0.59886193, 0.7773869, 0.5409347, 0.90715384, 0.7246512, 0.5628571, 0.94887644, 0.5051049, 0.6421311, 0.7446953, 0.56400037, 0.5506351, 0.47334778, 0.4654252, 0.790403, 0.47296175, 0.89295447, 0.8266279, 0.82453877, 1.0367845, 0.5797145, 0.4848579, 1.0229998, 0.69332045, 0.679363, 0.6570815, 0.5949688, 0.49552882, 0.9307511, 0.71564245, 0.87055635, 0.5387984, 0.65640783, 0.8515568, 0.7556637, 0.7556637, 0.6387657, 0.6168532, 0.98979753, 0.69501466, 0.57186943, 0.6394097, 0.8826074, 0.9292619, 0.96623814, 0.49233985, 0.5596475, 0.82805884, 1.0416745, 0.79624665, 0.78281283, 0.7494638, 0.63390017, 0.8020877, 0.5422508, 0.74879444, 0.40409353, 0.50668156, 0.42069715, 1.0652552, 0.72926956, 0.43253687, 0.47487485, 0.4292339, 0.88553303, 0.82552046, 0.7777172, 0.5536848, 0.78408533, 0.43867353, 0.40562358, 0.69246674, 0.38964713, 0.6034923, 0.85474813, 0.68130714, 0.44438317, 0.9320823, 0.5058337, 0.66779685, 0.43401352, 0.39696234, 0.78174835, 0.49193528, 0.8922436, 0.7647692, 0.6616655, 0.73046994, 0.63556933, 0.45500597, 0.9379884, 0.5029094, 0.5998908, 0.8571327, 0.88558906, 0.94974047, 1.0405205, 0.48550236, 0.73147774, 0.5354663, 0.90980905, 0.61992663, 0.5058703, 0.46397868, 0.78383285, 0.44841352, 0.52759033, 0.39917815, 0.5896204, 0.5975742, 0.6862365, 0.39837775, 0.95583606, 0.5980051, 0.66222453, 1.0654964, 0.8313978, 0.7511156, 0.973598, 0.97749126, 0.71736574, 0.7973428, 0.4283648, 0.49457812, 0.81592846, 0.42811957, 0.4689046, 0.932056, 0.564292, 0.51834124, 0.725082, 0.9262983, 0.7227144, 0.90896857, 0.6693698, 0.57502, 1.0313021, 0.7095211, 0.45981663, 0.6910606, 0.51306176, 0.677236, 0.6096732, 1.0204118, 0.41166714, 0.6231743, 0.43899566, 0.60631824, 0.6068907, 0.560803, 0.7546913, 0.8762449, 0.6985864, 0.7662474, 0.40078542, 0.77456504, 0.5239945, 0.6156836, 0.83958703, 0.50694776, 0.50694776, 0.6160756, 0.65951926, 0.80632275, 1.0621827, 0.49167317, 0.5579265, 0.8483528, 0.5138272, 0.9628796, 0.76615745, 0.9761975, 0.4818998, 0.69556844, 0.7151656, 1.0158787, 0.61395156, 0.7015463, 0.99944586, 0.51481533, 0.6999361, 0.70873207, 0.87477624, 0.46722096, 0.45796412, 0.5352152, 0.38793808, 0.6305862, 0.50720227, 0.45295644, 0.36782107, 0.8063331, 0.7028247, 0.5428181, 0.6026922, 0.5097531, 0.5097531, 0.50916696, 0.47778207, 0.8000927, 0.53853726, 0.35039365, 0.35039365, 0.560714, 0.7088619, 0.4442714, 0.77062094, 0.5519592, 0.51020396, 0.32579872, 0.80212665, 0.8760797, 0.72156894, 0.49728584, 0.3682756, 0.6938331, 0.8232431, 0.7 ...
# [ 857  902 2593 ...  703 2193 2188]

# %%
#print(res[11],train_labels[11])
print(train_labels[981])
# Out:
# 30

# %%
print(query_labels[30])
# Out:
# 37
